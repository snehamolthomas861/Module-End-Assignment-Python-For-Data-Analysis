# %% [markdown]
# Module End  Assignment: Python For Data Analysis
#
# “Social Media Engagement Analytics”

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ####❖ Task 1 — Data Import & Setup

# %%
df = pd.read_csv("/content/social_media_engagement_5000.csv")

# %%
df
# Out:
#       user_id   age  gender    country  post_id post_type post_category  \
# 0       25795  43.0  Female     Brazil   496713     image       fitness
# 1       10860  33.0    Male     Brazil   157326      reel          food
# 2       86820  32.0  Female         UK   109864      text          food
# 3       64886  51.0   Other     France   848877      text       fitness
# 4       16265  34.0   Other         UK   449706     image       fitness
# ...       ...   ...     ...        ...      ...       ...           ...
# 4995    59500  44.0    Male  Australia   441541     video     education
# 4996    22100  38.0   Other        UAE   677076      reel     education
# 4997    67021  63.0  Female        USA   273595      text        travel
# 4998    29800  13.0  Female    Germany   785644     video       fitness
# 4999    73400  54.0   Other      Japan   712252      text        travel
#
#         likes  comments  shares  watch_time_sec  impression_count   posted_at  \
# ...

# %%
df.head()
# Out:
#    user_id   age  gender country  post_id post_type post_category    likes  \
# 0    25795  43.0  Female  Brazil   496713     image       fitness   7011.0
# 1    10860  33.0    Male  Brazil   157326      reel          food  11750.0
# 2    86820  32.0  Female      UK   109864      text          food   4862.0
# 3    64886  51.0   Other  France   848877      text       fitness   5350.0
# 4    16265  34.0   Other      UK   449706     image       fitness  12682.0
#
#    comments  shares  watch_time_sec  impression_count   posted_at  \
# 0     354.0  1157.0            5726             44650  17-12-2022
# 1    2606.0  1807.0            5947             80216  02-06-2023
# 2     344.0   955.0            6946             44858  07-05-2023
# 3    1083.0  1049.0             229             70455  12-02-2023
# 4    2735.0  1300.0            4798              6019  23-05-2023
#
#    follower_count  is_verified device_type sentiment               hashtags  \
# ...

# %%
df.shape
# Out:
# (5000, 19)

# %%
df.columns
# Out:
# Index(['user_id', 'age', 'gender', 'country', 'post_id', 'post_type',
#        'post_category', 'likes', 'comments', 'shares', 'watch_time_sec',
#        'impression_count', 'posted_at', 'follower_count', 'is_verified',
#        'device_type', 'sentiment', 'hashtags', 'engagement_rate'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_id           5000 non-null   int64
#  1   age               4850 non-null   float64
#  2   gender            4850 non-null   object
#  3   country           5000 non-null   object
#  4   post_id           5000 non-null   int64
#  5   post_type         5000 non-null   object
#  6   post_category     5000 non-null   object
#  7   likes             4850 non-null   float64
#  8   comments          4850 non-null   float64
#  9   shares            4850 non-null   float64
#  10  watch_time_sec    5000 non-null   int64
#  11  impression_count  5000 non-null   int64
#  12  posted_at         5000 non-null   object
#  13  follower_count    5000 non-null   int64
#  14  is_verified       5000 non-null   bool
#  15  device_type       5000 non-null   object
# ...

# %%
df.dtypes
# Out:
# user_id               int64
# age                 float64
# gender               object
# country              object
# post_id               int64
# post_type            object
# post_category        object
# likes               float64
# comments            float64
# shares              float64
# watch_time_sec        int64
# impression_count      int64
# posted_at            object
# follower_count        int64
# is_verified            bool
# device_type          object
# sentiment            object
# hashtags             object
# engagement_rate     float64
# dtype: object

# %% [markdown]
# ####Task 2 — Data Cleaning

# %%
df.isnull().sum()
# Out:
# user_id               0
# age                 150
# gender              150
# country               0
# post_id               0
# post_type             0
# post_category         0
# likes               150
# comments            150
# shares              150
# watch_time_sec        0
# impression_count      0
# posted_at             0
# follower_count        0
# is_verified           0
# device_type           0
# sentiment           150
# hashtags              0
# engagement_rate       0
# dtype: int64

# %%
print("Gender values:")
print(df['gender'].value_counts(dropna=False))

print("\nSentiment values:")
print(df['sentiment'].value_counts(dropna=False))

print("\nAge statistics:")
print(df['age'].describe())

print("\nLikes statistics:")
print(df['likes'].describe())

print("\nComments statistics:")
print(df['comments'].describe())

print("\nShares statistics:")
print(df['shares'].describe())
# Out:
# Gender values:
# gender
# Male      1699
# Other     1581
# Female    1570
# NaN        150
# Name: count, dtype: int64
#
# Sentiment values:
# sentiment
# positive    2363
# neutral     1527
# negative     960
# NaN          150
# Name: count, dtype: int64
#
# Age statistics:
# count    4850.000000
# mean       38.454021
# std        14.912381
# min        13.000000
# 25%        26.000000
# 50%        38.000000
# 75%        51.000000
# max        64.000000
# Name: age, dtype: float64
#
# Likes statistics:
# count     4850.000000
# mean     10107.043711
# std       5789.819252
# min         10.000000
# 25%       5068.500000
# 50%      10105.500000
# 75%      15115.000000
# max      19998.000000
# Name: likes, dtype: float64
#
# Comments statistics:
# count    4850.000000
# mean     1502.195670
# std       869.537889
# min         0.000000
# 25%       760.000000
# 50%      1497.000000
# 75%      2256.000000
# max      2999.000000
# Name: comments, dtype: float64
#
# ...

# %%
# Fill missing numeric values with median
df['age'] = df['age'].fillna(df['age'].median())
df['likes'] = df['likes'].fillna(df['likes'].median())
df['comments'] = df['comments'].fillna(df['comments'].median())
df['shares'] = df['shares'].fillna(df['shares'].median())

# Fill missing categorical values with mode
df['gender'] = df['gender'].fillna(df['gender'].mode()[0])
df['sentiment'] = df['sentiment'].fillna(df['sentiment'].mode()[0])

# %%
df.isnull().sum()
# Out:
# user_id             0
# age                 0
# gender              0
# country             0
# post_id             0
# post_type           0
# post_category       0
# likes               0
# comments            0
# shares              0
# watch_time_sec      0
# impression_count    0
# posted_at           0
# follower_count      0
# is_verified         0
# device_type         0
# sentiment           0
# hashtags            0
# engagement_rate     0
# dtype: int64

# %%
df.shape
# Out:
# (5000, 19)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['posted_at'] = pd.to_datetime(df['posted_at'])
# Out:
# /tmp/ipykernel_530/1302919506.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['posted_at'] = pd.to_datetime(df['posted_at'])

# %%
df['posted_at'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.dtypes
# Out:
# user_id                      int64
# age                        float64
# gender                      object
# country                     object
# post_id                      int64
# post_type                   object
# post_category               object
# likes                      float64
# comments                   float64
# shares                     float64
# watch_time_sec               int64
# impression_count             int64
# posted_at           datetime64[ns]
# follower_count               int64
# is_verified                   bool
# device_type                 object
# sentiment                   object
# hashtags                    object
# engagement_rate            float64
# dtype: object

# %%
print("Gender values:")
print(df['gender'].unique())

print("\nSentiment values:")
print(df['sentiment'].unique())
# Out:
# Gender values:
# ['Female' 'Male' 'Other']
#
# Sentiment values:
# ['negative' 'positive' 'neutral']

# %%
print("Likes:", df['likes'].min(), "to", df['likes'].max())
print("Comments:", df['comments'].min(), "to", df['comments'].max())
print("Shares:", df['shares'].min(), "to", df['shares'].max())
# Out:
# Likes: 10.0 to 19998.0
# Comments: 0.0 to 2999.0
# Shares: 0.0 to 1999.0

# %%
df['hashtags'].head(10)
# Out:
# 0      #foodie #travel #love
# 1                   #fitness
# 2                    #foodie
# 3        #music #foodie #fun
# 4                    #travel
# 5                   #fitness
# 6                     #music
# 7    #travel #music #fitness
# 8       #music #fun #fitness
# 9           #lifestyle #love
# Name: hashtags, dtype: object

# %%
df['hashtag_count'] = df['hashtags'].str.count('#')

# %%
df[['hashtags', 'hashtag_count']].head(10)
# Out:
#                   hashtags  hashtag_count
# 0    #foodie #travel #love              3
# 1                 #fitness              1
# 2                  #foodie              1
# 3      #music #foodie #fun              3
# 4                  #travel              1
# 5                 #fitness              1
# 6                   #music              1
# 7  #travel #music #fitness              3
# 8     #music #fun #fitness              3
# 9         #lifestyle #love              2

# %%
df.isnull().sum()
# Out:
# user_id             0
# age                 0
# gender              0
# country             0
# post_id             0
# post_type           0
# post_category       0
# likes               0
# comments            0
# shares              0
# watch_time_sec      0
# impression_count    0
# posted_at           0
# follower_count      0
# is_verified         0
# device_type         0
# sentiment           0
# hashtags            0
# engagement_rate     0
# hashtag_count       0
# dtype: int64

# %%
df.shape
# Out:
# (5000, 20)

# %% [markdown]
# ####Task 3 — Data Exploration using Pandas

# %%
print("First 5 rows:")
display(df.head())

print("\nLast 5 rows:")
display(df.tail())
# Out:
# First 5 rows:
#    user_id   age  gender country  post_id post_type post_category    likes  \
# 0    25795  43.0  Female  Brazil   496713     image       fitness   7011.0
# 1    10860  33.0    Male  Brazil   157326      reel          food  11750.0
# 2    86820  32.0  Female      UK   109864      text          food   4862.0
# 3    64886  51.0   Other  France   848877      text       fitness   5350.0
# 4    16265  34.0   Other      UK   449706     image       fitness  12682.0
#
#    comments  shares  watch_time_sec  impression_count  posted_at  \
# 0     354.0  1157.0            5726             44650 2022-12-17
# 1    2606.0  1807.0            5947             80216 2023-06-02
# 2     344.0   955.0            6946             44858 2023-05-07
# 3    1083.0  1049.0             229             70455 2023-02-12
# 4    2735.0  1300.0            4798              6019 2023-05-23
#
#    follower_count  is_verified device_type sentiment               hashtags  \
# ...

# %%
print("Shape:")
print(df.shape)

print("\nColumns:")
print(df.columns.tolist())

print("\nData Types:")
print(df.dtypes)
# Out:
# Shape:
# (5000, 20)
#
# Columns:
# ['user_id', 'age', 'gender', 'country', 'post_id', 'post_type', 'post_category', 'likes', 'comments', 'shares', 'watch_time_sec', 'impression_count', 'posted_at', 'follower_count', 'is_verified', 'device_type', 'sentiment', 'hashtags', 'engagement_rate', 'hashtag_count']
#
# Data Types:
# user_id                      int64
# age                        float64
# gender                      object
# country                     object
# post_id                      int64
# post_type                   object
# post_category               object
# likes                      float64
# comments                   float64
# shares                     float64
# watch_time_sec               int64
# impression_count             int64
# posted_at           datetime64[ns]
# follower_count               int64
# is_verified                   bool
# device_type                 object
# sentiment                   object
# hashtags                    object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_id           5000 non-null   int64
#  1   age               5000 non-null   float64
#  2   gender            5000 non-null   object
#  3   country           5000 non-null   object
#  4   post_id           5000 non-null   int64
#  5   post_type         5000 non-null   object
#  6   post_category     5000 non-null   object
#  7   likes             5000 non-null   float64
#  8   comments          5000 non-null   float64
#  9   shares            5000 non-null   float64
#  10  watch_time_sec    5000 non-null   int64
#  11  impression_count  5000 non-null   int64
#  12  posted_at         5000 non-null   datetime64[ns]
#  13  follower_count    5000 non-null   int64
#  14  is_verified       5000 non-null   bool
#  15  device_type       5000 non-null   object
# ...

# %%
df.describe()
# Out:
#             user_id          age        post_id         likes     comments  \
# count   5000.000000  5000.000000    5000.000000   5000.000000  5000.000000
# mean   54561.890800    38.440400  548042.909000  10106.997400  1502.039800
# min    10055.000000    13.000000  100068.000000     10.000000     0.000000
# 25%    32309.500000    26.000000  322543.500000   5235.000000   792.000000
# 50%    54374.500000    38.000000  548077.500000  10105.500000  1497.000000
# 75%    77180.500000    51.000000  771574.500000  14959.000000  2235.250000
# max    99963.000000    64.000000  999455.000000  19998.000000  2999.000000
# std    26090.370121    14.687151  260646.957267   5702.293017   856.393312
#
#           shares  watch_time_sec  impression_count  \
# count  5000.0000     5000.000000       5000.000000
# mean   1002.9106     4014.503200      50013.732800
# min       0.0000        0.000000        105.000000
# 25%     511.0000     2017.750000      24988.250000
# ...

# %%
df.describe(include='object')
# Out:
#        gender country post_type post_category device_type sentiment hashtags
# count    5000    5000      5000          5000        5000      5000     5000
# unique      3      10         4             8           3         3      761
# top      Male   India      reel       fitness      mobile  positive    #tech
# freq     1849     535      1283           675        1684      2513      201

# %%
df['post_type'].value_counts()
# Out:
# post_type
# reel     1283
# image    1247
# text     1245
# video    1225
# Name: count, dtype: int64

# %%
df['country'].value_counts()
# Out:
# country
# India        535
# Canada       513
# Brazil       504
# UAE          503
# USA          501
# France       496
# UK           493
# Australia    493
# Germany      490
# Japan        472
# Name: count, dtype: int64

# %%
df['post_category'].value_counts()
# Out:
# post_category
# fitness      675
# tech         665
# music        635
# education    631
# lifestyle    607
# travel       600
# fashion      594
# food         593
# Name: count, dtype: int64

# %%
df['device_type'].value_counts()
# Out:
# device_type
# mobile     1684
# tablet     1658
# desktop    1658
# Name: count, dtype: int64

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# positive    2513
# neutral     1527
# negative     960
# Name: count, dtype: int64

# %%
df['hashtag_count'] = df['hashtags'].str.split().str.len()

# %%
df['gender'].unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
df['country'].unique()
# Out:
# array(['Brazil', 'UK', 'France', 'Canada', 'Japan', 'Australia', 'India',
#        'UAE', 'Germany', 'USA'], dtype=object)

# %%
df['post_type'].unique()
# Out:
# array(['image', 'reel', 'text', 'video'], dtype=object)

# %%
df['post_category'].unique()
# Out:
# array(['fitness', 'food', 'tech', 'travel', 'fashion', 'lifestyle',
#        'education', 'music'], dtype=object)

# %%
df['device_type'].unique()
# Out:
# array(['mobile', 'tablet', 'desktop'], dtype=object)

# %%
df['sentiment'].unique()
# Out:
# array(['negative', 'positive', 'neutral'], dtype=object)

# %%
df['gender'].nunique()
# Out:
# 3

# %%
df['country'].nunique()
# Out:
# 10

# %%
df['post_type'].nunique()
# Out:
# 4

# %%
df['post_category'].nunique()
# Out:
# 8

# %%
df['device_type'].nunique()
# Out:
# 3

# %%
df['sentiment'].nunique()
# Out:
# 3

# %%
categorical_cols = [
    'gender',
    'country',
    'post_type',
    'post_category',
    'device_type',
    'sentiment'
]

df[categorical_cols].nunique()
# Out:
# gender            3
# country          10
# post_type         4
# post_category     8
# device_type       3
# sentiment         3
# dtype: int64

# %%
numeric_df = df.select_dtypes(include='number')

# %%
correlation_matrix = numeric_df.corr()
correlation_matrix
# Out:
#                    user_id       age   post_id     likes  comments    shares  \
# user_id           1.000000 -0.006688  0.020051  0.025811 -0.033395  0.013763
# age              -0.006688  1.000000 -0.013153 -0.036322 -0.007284  0.013871
# post_id           0.020051 -0.013153  1.000000  0.014526 -0.010540  0.001846
# likes             0.025811 -0.036322  0.014526  1.000000 -0.018421  0.004712
# comments         -0.033395 -0.007284 -0.010540 -0.018421  1.000000  0.006142
# shares            0.013763  0.013871  0.001846  0.004712  0.006142  1.000000
# watch_time_sec   -0.016847  0.005542  0.018374  0.008710 -0.016351  0.014658
# impression_count  0.015326  0.013322 -0.007709  0.007952 -0.009395 -0.005204
# follower_count    0.010124 -0.024894 -0.002844 -0.022982 -0.011733 -0.010783
# engagement_rate  -0.004282  0.008039  0.010139  0.093520  0.000051  0.021724
# hashtag_count    -0.013692  0.007173  0.007344 -0.002190 -0.015230  0.013379
#
# ...

# %%
plt.figure(figsize=(12, 8))

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f'
)

plt.title('Correlation Matrix of Numeric Variables')
plt.show()

# %%
avg_likes_by_post_type = df.groupby('post_type')['likes'].mean()

avg_likes_by_post_type
# Out:
# post_type
# image    10104.865277
# reel     10037.802416
# text     10100.148193
# video    10188.600000
# Name: likes, dtype: float64

# %%
avg_impressions_by_country = df.groupby('country')['impression_count'].mean()

avg_impressions_by_country
# Out:
# country
# Australia    48346.383367
# Brazil       49193.174603
# Canada       48703.150097
# France       51727.673387
# Germany      48605.406122
# India        52462.386916
# Japan        49616.135593
# UAE          48928.413519
# UK           51119.393509
# USA          51263.872255
# Name: impression_count, dtype: float64

# %%
df.groupby('post_category')['likes'].mean()
# Out:
# post_category
# education    10126.487322
# fashion       9843.356902
# fitness       9914.602222
# food         10225.522766
# lifestyle    10180.559308
# music        10205.749606
# tech         10171.571429
# travel       10196.304167
# Name: likes, dtype: float64

# %%
df.groupby('post_type')['comments'].mean()
# Out:
# post_type
# image    1525.235766
# reel     1504.187062
# text     1499.106024
# video    1479.160000
# Name: comments, dtype: float64

# %%
df.groupby('post_type')['shares'].mean()
# Out:
# post_type
# image    1019.289495
# reel      982.042089
# text     1013.989558
# video     996.834286
# Name: shares, dtype: float64

# %%
df.groupby('post_category')['engagement_rate'].mean()
# Out:
# post_category
# education    0.844222
# fashion      0.807109
# fitness      0.865628
# food         1.358628
# lifestyle    1.091019
# music        0.888803
# tech         1.160475
# travel       0.702223
# Name: engagement_rate, dtype: float64

# %%
df.groupby('country')['watch_time_sec'].mean()
# Out:
# country
# Australia    4150.675456
# Brazil       4049.206349
# Canada       4003.695906
# France       3992.747984
# Germany      3976.377551
# India        4016.835514
# Japan        3878.387712
# UAE          4007.823062
# UK           4118.693712
# USA          3945.413174
# Name: watch_time_sec, dtype: float64

# %%
avg_likes_post_type = (
    df.groupby('post_type', as_index=False)['likes']
      .mean()
      .sort_values('likes', ascending=False)
)

avg_likes_post_type
# Out:
#   post_type         likes
# 3     video  10188.600000
# 0     image  10104.865277
# 2      text  10100.148193
# 1      reel  10037.802416

# %%
avg_impressions_country = (
    df.groupby('country', as_index=False)['impression_count']
      .mean()
      .sort_values('impression_count', ascending=False)
)

avg_impressions_country
# Out:
#      country  impression_count
# 5      India      52462.386916
# 3     France      51727.673387
# 9        USA      51263.872255
# 8         UK      51119.393509
# 6      Japan      49616.135593
# 1     Brazil      49193.174603
# 7        UAE      48928.413519
# 2     Canada      48703.150097
# 4    Germany      48605.406122
# 0  Australia      48346.383367

# %%
numeric_cols = [
    'age',
    'likes',
    'comments',
    'shares',
    'watch_time_sec',
    'impression_count',
    'follower_count',
    'engagement_rate',
    'hashtag_count'
]

correlation_matrix = df[numeric_cols].corr()

print(correlation_matrix)
# Out:
#                        age     likes  comments    shares  watch_time_sec  \
# age               1.000000 -0.036322 -0.007284  0.013871        0.005542
# likes            -0.036322  1.000000 -0.018421  0.004712        0.008710
# comments         -0.007284 -0.018421  1.000000  0.006142       -0.016351
# shares            0.013871  0.004712  0.006142  1.000000        0.014658
# watch_time_sec    0.005542  0.008710 -0.016351  0.014658        1.000000
# impression_count  0.013322  0.007952 -0.009395 -0.005204       -0.004335
# follower_count   -0.024894 -0.022982 -0.011733 -0.010783        0.002761
# engagement_rate   0.008039  0.093520  0.000051  0.021724       -0.001148
# hashtag_count     0.007173 -0.002190 -0.015230  0.013379       -0.023301
#
#                   impression_count  follower_count  engagement_rate  \
# age                       0.013322       -0.024894         0.008039
# likes                     0.007952       -0.022982         0.093520
# ...

# %%
print("Average Likes by Post Type:")
print(df.groupby('post_type')['likes'].mean().sort_values(ascending=False))

print("\nAverage Impressions by Country:")
print(df.groupby('country')['impression_count'].mean().sort_values(ascending=False))
# Out:
# Average Likes by Post Type:
# post_type
# video    10188.600000
# image    10104.865277
# text     10100.148193
# reel     10037.802416
# Name: likes, dtype: float64
#
# Average Impressions by Country:
# country
# India        52462.386916
# France       51727.673387
# USA          51263.872255
# UK           51119.393509
# Japan        49616.135593
# Brazil       49193.174603
# UAE          48928.413519
# Canada       48703.150097
# Germany      48605.406122
# Australia    48346.383367
# Name: impression_count, dtype: float64

# %% [markdown]
# ####Task 4 — Data Wrangling

# %%
df['engagement_score'] = df['likes'] + df['comments'] + df['shares']

# %%
df[['likes', 'comments', 'shares', 'engagement_score']].head()
# Out:
#      likes  comments  shares  engagement_score
# 0   7011.0     354.0  1157.0            8522.0
# 1  11750.0    2606.0  1807.0           16163.0
# 2   4862.0     344.0   955.0            6161.0
# 3   5350.0    1083.0  1049.0            7482.0
# 4  12682.0    2735.0  1300.0           16717.0

# %%
df[['hashtags', 'hashtag_count']].head()
# Out:
#                 hashtags  hashtag_count
# 0  #foodie #travel #love              3
# 1               #fitness              1
# 2                #foodie              1
# 3    #music #foodie #fun              3
# 4                #travel              1

# %%
post_type_summary = df.groupby('post_type')[['likes', 'comments', 'shares', 'engagement_score']].mean()

print(post_type_summary)
# Out:
#                   likes     comments       shares  engagement_score
# post_type
# image      10104.865277  1525.235766  1019.289495      12649.390537
# reel       10037.802416  1504.187062   982.042089      12524.031567
# text       10100.148193  1499.106024  1013.989558      12613.243775
# video      10188.600000  1479.160000   996.834286      12664.594286

# %%
country_summary = df.groupby('country')[['likes', 'comments', 'shares', 'engagement_score']].mean()

print(country_summary)
# Out:
#                   likes     comments       shares  engagement_score
# country
# Australia  10294.124746  1485.803245  1029.693712      12809.621704
# Brazil      9886.689484  1490.434524  1008.859127      12385.983135
# Canada     10063.066277  1546.582846   996.245614      12605.894737
# France     10372.876008  1478.695565  1051.812500      12903.384073
# Germany    10130.458163  1531.826531   973.379592      12635.664286
# India       9962.468224  1494.917757  1035.315888      12492.701869
# Japan      10088.862288  1530.434322   959.351695      12578.648305
# UAE        10227.487078  1541.214712   989.075547      12757.777336
# UK          9935.650101  1463.042596   985.681542      12384.374239
# USA        10122.361277  1457.958084   995.141717      12575.461078

# %%
sentiment_summary = df.groupby('sentiment')[['likes', 'comments', 'shares', 'engagement_score']].mean()

print(sentiment_summary)
# Out:
#                   likes     comments       shares  engagement_score
# sentiment
# negative   10208.096875  1516.094792  1007.307292      12731.498958
# neutral     9923.194499  1528.404060   996.565160      12448.163720
# positive   10180.062077  1480.650617  1005.086749      12665.799443

# %% [markdown]
# ####Task 5 — Statistical Analysis

# %%
stats_cols = [
    'likes',
    'comments',
    'shares',
    'watch_time_sec',
    'engagement_rate',
    'follower_count'
]

# %%
print("Mean:")
print(df[stats_cols].mean())

print("\nMedian:")
print(df[stats_cols].median())

print("\nMode:")
print(df[stats_cols].mode().iloc[0])
# Out:
# Mean:
# likes               10106.997400
# comments             1502.039800
# shares               1002.910600
# watch_time_sec       4014.503200
# engagement_rate         0.964356
# follower_count     393698.224800
# dtype: float64
#
# Median:
# likes               10105.500000
# comments             1497.000000
# shares               1012.000000
# watch_time_sec       4034.500000
# engagement_rate         0.253896
# follower_count     388982.000000
# dtype: float64
#
# Mode:
# likes               10105.500000
# comments             1497.000000
# shares               1012.000000
# watch_time_sec        916.000000
# engagement_rate         0.006363
# follower_count     497502.000000
# Name: 0, dtype: float64

# %%
print("Standard Deviation:")
print(df[stats_cols].std())

print("\nVariance:")
print(df[stats_cols].var())
# Out:
# Standard Deviation:
# likes                5702.293017
# comments              856.393312
# shares                570.855200
# watch_time_sec       2308.096459
# engagement_rate         5.318029
# follower_count     230927.884535
# dtype: float64
#
# Variance:
# likes              3.251615e+07
# comments           7.334095e+05
# shares             3.258757e+05
# watch_time_sec     5.327309e+06
# engagement_rate    2.828143e+01
# follower_count     5.332769e+10
# dtype: float64

# %%
print("Percentiles:")
print(df[stats_cols].quantile([0.25, 0.50, 0.75]))
# Out:
# Percentiles:
#         likes  comments  shares  watch_time_sec  engagement_rate  \
# 0.25   5235.0    792.00   511.0         2017.75         0.145781
# 0.50  10105.5   1497.00  1012.0         4034.50         0.253896
# 0.75  14959.0   2235.25  1483.0         6020.25         0.504794
#
#       follower_count
# 0.25       194480.00
# 0.50       388982.00
# 0.75       589744.25

# %%
print("25th Percentile:")
print(df[stats_cols].quantile(0.25))

print("\n50th Percentile:")
print(df[stats_cols].quantile(0.50))

print("\n75th Percentile:")
print(df[stats_cols].quantile(0.75))
# Out:
# 25th Percentile:
# likes                5235.000000
# comments              792.000000
# shares                511.000000
# watch_time_sec       2017.750000
# engagement_rate         0.145781
# follower_count     194480.000000
# Name: 0.25, dtype: float64
#
# 50th Percentile:
# likes               10105.500000
# comments             1497.000000
# shares               1012.000000
# watch_time_sec       4034.500000
# engagement_rate         0.253896
# follower_count     388982.000000
# Name: 0.5, dtype: float64
#
# 75th Percentile:
# likes               14959.000000
# comments             2235.250000
# shares               1483.000000
# watch_time_sec       6020.250000
# engagement_rate         0.504794
# follower_count     589744.250000
# Name: 0.75, dtype: float64

# %%
print("Skewness:")
print(df[stats_cols].skew())

print("\nKurtosis:")
print(df[stats_cols].kurt())
# Out:
# Skewness:
# likes              -0.006894
# comments            0.003802
# shares             -0.014654
# watch_time_sec     -0.018196
# engagement_rate    18.781271
# follower_count      0.041118
# dtype: float64
#
# Kurtosis:
# likes               -1.149992
# comments            -1.144375
# shares              -1.146857
# watch_time_sec      -1.195652
# engagement_rate    482.991739
# follower_count      -1.189474
# dtype: float64

# %%
statistical_summary = df[stats_cols].agg(
    ['mean', 'median', 'std', 'var']
)

print(statistical_summary)
# Out:
#                likes       comments        shares  watch_time_sec  \
# mean    1.010700e+04    1502.039800    1002.91060    4.014503e+03
# median  1.010550e+04    1497.000000    1012.00000    4.034500e+03
# std     5.702293e+03     856.393312     570.85520    2.308096e+03
# var     3.251615e+07  733409.504917  325875.65934    5.327309e+06
#
#         engagement_rate  follower_count
# mean           0.964356    3.936982e+05
# median         0.253896    3.889820e+05
# std            5.318029    2.309279e+05
# var           28.281435    5.332769e+10

# %% [markdown]
# ####Task 6 — Data Visualization (Min. 8 Plots Required)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
plt.figure(figsize=(8, 5))

plt.scatter(df['likes'], df['impression_count'])

plt.xlabel('Likes')
plt.ylabel('Impressions')
plt.title('Likes vs Impressions')

plt.show()

# %%
daily_engagement = df.groupby(
    df['posted_at'].dt.date
)['engagement_score'].mean()

# %%
plt.figure(figsize=(12, 5))

plt.plot(daily_engagement.index, daily_engagement.values)

plt.xlabel('Date')
plt.ylabel('Average Engagement Score')
plt.title('Daily Engagement Trend')

plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
category_counts = df['post_category'].value_counts()

plt.figure(figsize=(10, 5))

plt.bar(category_counts.index, category_counts.values)

plt.xlabel('Post Category')
plt.ylabel('Number of Posts')
plt.title('Posts by Category')

plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
gender_counts = df['gender'].value_counts()

plt.figure(figsize=(7, 7))

plt.pie(
    gender_counts.values,
    labels=gender_counts.index,
    autopct='%1.1f%%'
)

plt.title('Gender Distribution')

plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.hist(df['age'], bins=10)

plt.xlabel('Age')
plt.ylabel('Number of Users')
plt.title('Age Distribution')

plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.boxplot(df['engagement_rate'])

plt.ylabel('Engagement Rate')
plt.title('Engagement Rate Distribution')

plt.show()

# %% [markdown]
# #### Seaborn

# %%
plt.figure(figsize=(8, 5))

sns.countplot(data=df, x='post_type')

plt.xlabel('Post Type')
plt.ylabel('Number of Posts')
plt.title('Post Type Distribution')

plt.show()

# %%
plt.figure(figsize=(10, 5))

sns.barplot(
    data=df,
    x='post_category',
    y='likes',
    estimator='mean'
)

plt.xlabel('Post Category')
plt.ylabel('Average Likes')
plt.title('Average Likes by Post Category')

plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.violinplot(
    data=df,
    x='sentiment',
    y='follower_count'
)

plt.xlabel('Sentiment')
plt.ylabel('Follower Count')
plt.title('Followers vs Sentiment')

plt.show()

# %%
plt.figure(figsize=(10, 7))

correlation = df[stats_cols].corr()

sns.heatmap(
    correlation,
    annot=True,
    fmt='.2f'
)

plt.title('Correlation Matrix')

plt.show()

# %%
sns.pairplot(
    df[stats_cols]
)

plt.show()

# %%
sns.pairplot(
    df[stats_cols].sample(500)
)

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.swarmplot(
    data=df.sample(500),
    x='device_type',
    y='engagement_score'
)

plt.xlabel('Device Type')
plt.ylabel('Engagement Score')
plt.title('Engagement Score by Device Type')

plt.show()

# %% [markdown]
# ####Plotly Interactive Visualization

# %%
category_likes = (
    df.groupby('post_category', as_index=False)['likes']
    .mean()
)

fig = px.bar(
    category_likes,
    x='post_category',
    y='likes',
    title='Average Likes by Post Category',
    labels={
        'post_category': 'Post Category',
        'likes': 'Average Likes'
    }
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
'engagement_score' in df.columns
# Out:
# True

# %%
df[['likes', 'comments', 'shares', 'engagement_score']].head()
# Out:
#      likes  comments  shares  engagement_score
# 0   7011.0     354.0  1157.0            8522.0
# 1  11750.0    2606.0  1807.0           16163.0
# 2   4862.0     344.0   955.0            6161.0
# 3   5350.0    1083.0  1049.0            7482.0
# 4  12682.0    2735.0  1300.0           16717.0

# %%
(df['engagement_score'] ==
 df['likes'] + df['comments'] + df['shares']).all()
# Out:
# np.True_

# %%
daily_engagement = df.groupby(
    df['posted_at'].dt.date
)['engagement_score'].mean()

# %%
plt.figure(figsize=(12, 5))

plt.plot(daily_engagement.index, daily_engagement.values)

plt.xlabel('Date')
plt.ylabel('Average Engagement Score')
plt.title('Daily Engagement Trend')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Final Insights

# %% [markdown]
# ####Content Performance

# %% [markdown]
# ####Which post types have highest engagement?

# %%
df.groupby('post_type')[[
    'likes', 'comments', 'shares', 'engagement_score'
]].mean()
# Out:
#                   likes     comments       shares  engagement_score
# post_type
# image      10104.865277  1525.235766  1019.289495      12649.390537
# reel       10037.802416  1504.187062   982.042089      12524.031567
# text       10100.148193  1499.106024  1013.989558      12613.243775
# video      10188.600000  1479.160000   996.834286      12664.594286

# %% [markdown]
# ####Best-performing content category?

# %%
category_engagement = df.groupby(
    'post_category'
)['engagement_score'].mean().sort_values(ascending=False)

print(category_engagement)
# Out:
# post_category
# music        12788.549606
# food         12739.200675
# tech         12686.490226
# travel       12650.559167
# lifestyle    12639.539539
# education    12578.270206
# fitness      12457.791852
# fashion      12356.420875
# Name: engagement_score, dtype: float64

# %% [markdown]
# ####Which countries have highest avg engagement rate?

# %%
country_engagement_rate = df.groupby(
    'country'
)['engagement_rate'].mean().sort_values(ascending=False)

print(country_engagement_rate)
# Out:
# country
# Brazil       1.540704
# Australia    1.324339
# France       1.146402
# UAE          1.112352
# Canada       0.916659
# UK           0.850966
# Japan        0.769623
# Germany      0.759000
# India        0.655005
# USA          0.576580
# Name: engagement_rate, dtype: float64

# %% [markdown]
# ####User Trends

# %% [markdown]
# ####How age affects engagement

# %%
df['age_group'] = pd.cut(
    df['age'],
    bins=[0, 18, 25, 35, 45, 100],
    labels=['Under 18', '18-25', '26-35', '36-45', '46+']
)

# %%
age_engagement = df.groupby(
    'age_group',
    observed=True
)['engagement_score'].mean()

print(age_engagement)
# Out:
# age_group
# Under 18    12991.711538
# 18-25       12628.408385
# 26-35       12768.703874
# 36-45       12741.579461
# 46+         12320.326013
# Name: engagement_score, dtype: float64

# %% [markdown]
# ####Performance difference for verified accounts

# %%
verified_engagement = df.groupby(
    'is_verified'
)['engagement_score'].mean()

print(verified_engagement)
# Out:
# is_verified
# False    12644.311822
# True     12309.280538
# Name: engagement_score, dtype: float64

# %%
category_engagement = df.groupby(
    'post_category'
)['engagement_score'].mean().sort_values(ascending=False)

print(category_engagement)
# Out:
# post_category
# music        12788.549606
# food         12739.200675
# tech         12686.490226
# travel       12650.559167
# lifestyle    12639.539539
# education    12578.270206
# fitness      12457.791852
# fashion      12356.420875
# Name: engagement_score, dtype: float64

# %% [markdown]
# | Age Group | Avg. Engagement Score |
# | --------- | --------------------: |
# | Under 18  |         **12,991.71** |
# | 26–35     |             12,768.70 |
# | 36–45     |             12,741.58 |
# | 18–25     |             12,628.41 |
# | 46+       |             12,320.33 |

# %% [markdown]
# Insight: The Under 18 group has the highest average engagement score, while the 46+ group has the lowest. Engagement varies across age groups, with the youngest group showing the highest average in this dataset.
#
# In short Engagement differs across age groups.

# %%
Account Status	     Avg. Engagement Score
Not Verified	       12,644.31
Verified	           12,309.28

# %% [markdown]
# Insight: In this dataset, non-verified accounts have a higher average engagement score than verified accounts.

# %% [markdown]
# •	Video posts have the highest average engagement score among post types.
#
#
# •	Music is the highest-engaging post category, followed by Food and Tech.
#
#
# •	Brazil has the highest average engagement rate among the countries in the dataset.
#
#
# •	Engagement varies across age groups, with Under 18 showing the highest average engagement score.
#
#
# •	Non-verified accounts have a higher average engagement score than verified accounts in this dataset.
#
#
# •	Overall, the differences between post types are relatively small, while category, country, age group, and verification status show more noticeable differences.

# %% [markdown]
# #### Behavioral Insights

# %% [markdown]
# ####Best time of day for impressions

# %%
df['hour'] = df['posted_at'].dt.hour

# %%
hourly_impressions = df.groupby('hour')['impression_count'].mean().sort_values(ascending=False)

print(hourly_impressions)
# Out:
# hour
# 0    50013.7328
# Name: impression_count, dtype: float64

# %% [markdown]
# Hour	   -     Avg Impressions
#
#
# 0 (12 AM)	 -   50,013.73

# %% [markdown]
# Insight: In this dataset, posts made at 12 AM (midnight) have an average of 50,013.73 impressions, making it the identified highest-impression hour.

# %% [markdown]
# ####Device type impact on watch time

# %%
device_watch_time = df.groupby('device_type')['watch_time_sec'].mean().sort_values(ascending=False)

print(device_watch_time)
# Out:
# device_type
# mobile     4087.830760
# tablet     3979.736429
# desktop    3974.792521
# Name: watch_time_sec, dtype: float64

# %% [markdown]
# Device Type   -  	Avg. Watch Time (sec)
#
#
# Mobile    -     	4,087.83
#
#
# Tablet	  -       3,979.74
#
#
# Desktop	  -       3,974.79

# %% [markdown]
# Insight: Mobile users have the highest average watch time at 4,087.83 seconds, followed by tablet and desktop users. This indicates that, in this dataset, mobile users spend slightly more time watching content.

# %% [markdown]
# ####Sentiment Analysis

# %% [markdown]
# ####Which sentiment performs best

# %% [markdown]
# Sentiment  -  Avg.Engagement Score
#
#
# Negative	 -   12,731.50
#
#
# Positive	 -   12,665.80
#
#
# Neutral  	 -   12,448.16

# %% [markdown]
# Insight: In this dataset, negative sentiment posts have the highest average engagement score, followed by positive posts. Neutral posts have the lowest.
# Looking at the individual engagement metrics:
#
#
# •	Negative posts have the highest average likes: 10,208.10
#
#
# •	Neutral posts have the highest average comments: 1,528.40
#
#
# •	Negative posts have the highest average shares: 1,007.31
#
#
# •	Positive posts have the highest average impressions: 50,248.11
#
#
# So negative posts achieve the highest overall engagement score, while positive posts receive slightly more impressions.

# %% [markdown]
# ####Behavior of negative/neutral sentiment posts

# %%
sentiment_summary = df.groupby('sentiment').agg({
    'likes': 'mean',
    'comments': 'mean',
    'shares': 'mean',
    'engagement_score': 'mean',
    'impression_count': 'mean'
})

print(sentiment_summary)
# Out:
#                   likes     comments       shares  engagement_score  \
# sentiment
# negative   10208.096875  1516.094792  1007.307292      12731.498958
# neutral     9923.194499  1528.404060   996.565160      12448.163720
# positive   10180.062077  1480.650617  1005.086749      12665.799443
#
#            impression_count
# sentiment
# negative       50191.960417
# neutral        49515.971185
# positive       50248.107441

# %% [markdown]
# Negative posts:
#
#
# •	Avg. likes: 10,208.10
#
#
# •	Avg. comments: 1,516.09
#
#
# •	Avg. shares: 1,007.31
#
#
# •	Avg. impressions: 50,191.96
#
#
# •	Avg. engagement score: 12,731.50
#
#
# Neutral posts:
#
#
# •	Avg. likes: 9,923.19
#
#
# •	Avg. comments: 1,528.40
#
#
# •	Avg. shares: 996.57
#
#
# •	Avg. impressions: 49,515.97
#
#
# •	Avg. engagement score: 12,448.16
#
#
# Insight: Negative posts receive more likes and shares than neutral posts, resulting in a higher overall engagement score. Neutral posts receive slightly more comments, but have lower likes, shares, impressions, and overall engagement.

# %% [markdown]
# Behavioral Insights
#
#
# Best time for impressions: 12 AM, with an average of 50,013.73 impressions in this dataset.
#
#
# Device impact: Mobile users have the highest average watch time (4,087.83 seconds), while desktop users have the lowest (3,974.79 seconds).
#
#
# Sentiment Analysis
#
#
# Negative sentiment posts have the highest average engagement score (12,731.50).
#
#
# Positive sentiment posts have the highest average impressions (50,248.11).
#
#
# Neutral sentiment posts have the lowest average engagement score (12,448.16).
#
#
# Negative posts receive more likes and shares than neutral posts, while neutral posts receive slightly more comments.
